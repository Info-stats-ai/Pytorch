# %%
import torch

# %%
x = torch.tensor(3.0, requires_grad=True)
# it will provide the derivative by
#requires_grad=True

# %%
x
# Out:
# tensor(3., requires_grad=True)

# %%
y = x**2

# %%
y
# Out:
# tensor(9., grad_fn=<PowBackward0>)

# %% [markdown]
# #### grad_fn=<PowBackward0> means?
# - It creates a computational graph x - sq-y: moves forward gives y = x**2
# - If it moves backwards it gives y= 2x
# - It means when moving backwards it provide the derivates

# %%
x
# Out:
# tensor(3., requires_grad=True)

# %%
y.backward()

# %%
x.grad
# Out:
# tensor(6.)

# %%
x = torch.tensor(2.0, requires_grad=True)

# %%
y = x**2

# %%
z = torch.sin(y)

# %%
y
# Out:
# tensor(4., grad_fn=<PowBackward0>)

# %%
z
# Out:
# tensor(-0.7568, grad_fn=<SinBackward0>)

# %%
z.backward()

# %%
x.grad
# Out:
# tensor(-2.6146)

# %%
x = torch.tensor(6.7)
y = torch.tensor(0.0)

# %%
x
# Out:
# tensor(6.7000)

# %%
y
# Out:
# tensor(0.)

# %%
w = torch.tensor(1.0, requires_grad=True)
b = torch.tensor(0.0, requires_grad=True)

# %%
w
# Out:
# tensor(1., requires_grad=True)

# %%
b
# Out:
# tensor(0., requires_grad=True)

# %%
z = w*x +b

# %%
z
# Out:
# tensor(6.7000, grad_fn=<AddBackward0>)

# %%
y_pred = torch.sigmoid(z)

# %%
loss =torch.binary_cross_entropy_with_logits(y_pred, y)

# %%
loss
# Out:
# tensor(1.3124, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)

# %%
loss.backward()

# %%
print(w.grad)
print(b.grad)
# Out:
# tensor(0.0060)
# tensor(0.0009)

# %%
x = torch.tensor([1.0,2.0,3.0], requires_grad=True)

# %%
x
# Out:
# tensor([1., 2., 3.], requires_grad=True)

# %%
y = (x**2).mean()
y
# Out:
# tensor(4.6667, grad_fn=<MeanBackward0>)

# %%
y.backward()

# %%
x.grad
# Out:
# tensor([0.6667, 1.3333, 2.0000])

# %%
# clearing grad
x.grad.zero_()
# Out:
# tensor([0., 0., 0.])

# %%
# gradient tracking disabling
x = torch.tensor([1.0,2.0,3.0], requires_grad=True)
x
# Out:
# tensor([1., 2., 3.], requires_grad=True)

# %%
y = x**3
y
# Out:
# tensor([ 1.,  8., 27.], grad_fn=<PowBackward0>)

# %%
y = (x**3).mean()
y.backward()

# %%
x.grad
# Out:
# tensor([1., 4., 9.])

# %%
# 1. requires_grad_(False)
# 2. detach()
# 3. wrap in torch.no_grad()

# %%
x.requires_grad_(False)
# Out:
# tensor([1., 2., 3.])

# %%
y = x**2

# %%
y
# Out:
# tensor([1., 4., 9.])

# %%
y.bac

# %%
x.grad
# Out:
# tensor([1., 4., 9.])

# %%
### Detach - create a new tensor
z = x.detach()

# %%
z # no graient tracking
# Out:
# tensor([1., 2., 3.])

# %%
y = (x**2).mean()
y
# Out:
# tensor(4.6667)

# %%
y1 = z**2
y1
# Out:
# tensor([1., 4., 9.])

# %%
y.backward()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-48-2702909622.py in <cell line: 0>()
# ----> 1 y.backward()
#
# /usr/local/lib/python3.11/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     624                 inputs=inputs,
#     625             )
# --> 626         torch.autograd.backward(
#     627             self, gradient, retain_graph, create_graph, inputs=inputs
#     628         )
#
# /usr/local/lib/python3.11/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     345     # some Python versions print out the first line of a multi-line function
#     346     # calls in the traceback and some print out the last line
# --> 347     _engine_run_backward(
#     348         tensors,
#     349         grad_tensors_,
#
# ...

# %%
y1.backward()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-89-3844781142.py in <cell line: 0>()
# ----> 1 y1.backward()
#
# /usr/local/lib/python3.11/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     624                 inputs=inputs,
#     625             )
# --> 626         torch.autograd.backward(
#     627             self, gradient, retain_graph, create_graph, inputs=inputs
#     628         )
#
# /usr/local/lib/python3.11/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     345     # some Python versions print out the first line of a multi-line function
#     346     # calls in the traceback and some print out the last line
# --> 347     _engine_run_backward(
#     348         tensors,
#     349         grad_tensors_,
#
# ...

# %%
# torch np grad
